# %% [markdown]
# # Rotation

# %% [markdown]
# Similar to translation, and perhaps unsurprisingly, rotation by an angle, 0 can be defined by constructing a matrix M in the form:

# %% [markdown]
# ### import the necessary packages

# %%
from matplotlib import pyplot as plt
import numpy as np
import imutils
import cv2

# %% [markdown]
# ### load the image and show it

# %%
image = cv2.imread("image/img.jpg")
plt.imshow(image)
plt.show()

# %% [markdown]
# ### grab the dimensions of the image and calculate the center of the image

# %%
(h, w) = image.shape[:2]
(cX, cY) = (w / 2, h / 2)

# %% [markdown]
# ### rotate our image by 45 degrees

# %%
M = cv2.getRotationMatrix2D((cX, cY), 45, 1)

rotated = cv2.warpAffine(image, M, (w, h))
plt.imshow(rotated)
plt.show()

# %% [markdown]
# ### rotate our image by -90 degrees

# %%
M = cv2.getRotationMatrix2D((cX, cY), -90, 1)

rotated = cv2.warpAffine(image, M, (w, h))
plt.imshow(rotated)
plt.show()

# %% [markdown]
# ### rotate our image around an arbitrary point rather than the center

# %%
M = cv2.getRotationMatrix2D((cX - 500, cY - 500), 45, 1.0)

rotated = cv2.warpAffine(image, M, (w, h))
plt.imshow(rotated)
plt.show()

# %% [markdown]
# ### finally, let's use our helper function in imutils to rotate the image by 180 degrees (flipping it upside down)

# %%
rotated = imutils.rotate(image, 180)s
plt.imshow(rotated)
plt.show()
